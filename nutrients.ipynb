# %%
# import libraries
import pandas as pd
import plotly.graph_objects as go

# %%
# load data
data = pd.read_csv("nutrients.csv", sep=";")

# %%
# preview data
data.head()
# Out:
#                         Nom vernaculaire     Nom scientifique Type d’algue  \
# 0  Wakamé atlantique ou Wakamé irlandais     Alaria esculenta        brune
# 1       Ascophylle noueux ou Goémon noir  Ascophyllum nodosum        brune
# 2                       Fucus vésiculeux    Fucus vesiculosus        brune
# 3                         Varech dentelé       Fucus serratus        brune
# 4                                  Fucus           Fucus spp.        brune
#
#    Couleur  Inclusion Fibres Minéraux Glucides Protéines   Eau Lipides  \
# 0  #E58005          0   42,9     21,3     13,3      12,2   8,7     1,5
# 1  #E58005          0   43,6     19,3     16,3       7,4  10,7     2,7
# 2  #E58005          0   46,7     20,7     14,9       6,4   9,2     2,1
# 3  #E58005          0   30,8     20,7     25,8      11,5   9,2     1,2
# 4  #E58005          1   46,3     21,2     12,4       9,1   9,2     1,7
#
#   Polyphénols
# 0         1,0
# 1         4,0
# 2         5,9
# 3         3,1
# 4         4,2

# %%
# drop unused data
mask_keep = data["Inclusion"] == 1
data = data.loc[mask_keep, :].reset_index(drop=True)
data = data.drop(["Minéraux", "Polyphénols"], axis=1)

# %%
# format scientific name
mask_nan = data["Nom scientifique"].isnull()
data.loc[mask_nan, "Nom scientifique"] = ""

# %%
# format numbers from strings to float
columns = data.columns[5:]
for column in columns:
    data.loc[:, column] = [strnb.replace(",", ".") for strnb in data.loc[:, column]]
data[columns] = data[columns].astype("float")

# %%
fig = go.Figure()
config = {'displayModeBar': True}

customscale = [[ 0.0, "#CCE9FF"], [1.0, "#007DED"]]

fig.add_trace(
    go.Heatmap(
        z=data[columns],
        x="<b>" + columns + "</b>",
        y="""<span style="color:""" + data["Couleur"] + """"><b>""" + \
            data["Nom vernaculaire"] + "</b><br><i>" + data["Nom scientifique"] + """</i></span>""",
        text=data[columns].astype(str),
        texttemplate="%{text}",
        textfont=dict(size=10),
        colorscale=customscale,
        showscale=False,
        hoverinfo="skip"
    ),
)

fig.update_xaxes(
    showgrid=False,
    side="top",
    tickangle=0,
    ticklabelstandoff=10,
    color="#007DED"
),

fig.update_yaxes(
    showgrid=False,
    tickangle=0,
    ticklabelstandoff=10,
    autorange="reversed"
)

fig.update_layout(
    plot_bgcolor="white",
    margin=dict(
        t=20,
        b=20,
        l=20,
        r=20
    ),
    modebar=dict(
        orientation="h",
    ),
    height=1000,
    width=800
)

fig.show(config=config)

# %%
fig.write_html("nutrients.html", include_plotlyjs="cdn")
